# %% [markdown]
# <a href="https://colab.research.google.com/github/STIPHAN89/test-colab/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello word')
# Out:
# hello word
